# %%
import pandas as pd 
  
df = pd.read_excel("National+education+cost+data.xlsx") 
print(df)
# Out:
#    TABLE CP-1. Average Tuition and Fees (Unweighted) in Current Dollars and in 2023 Dollars, 1986-87 to 2023-24  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                               86-87
# 3                                               87-88
# 4                                               88-89
# 5                                               89-90
# 6                                               90-91
# 7                                               91-92
# 8                                               92-93
# 9                                               93-94
# 10                                              94-95
# 11                                              95-96
# 12                                              96-97
# 13                                              97-98
# 14                                              98-99
# ...
